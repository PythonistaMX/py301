# %%
import data.analisis_twitter as at
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# !pip install nltk networkx twitter WordCloud

# %%
at.main()

# %%
 tuits = at.carga_tuits('tuits.json')

# %%
len(tuits)
# Out:
# 600

# %%
tuits[20]['text']
# Out:
# 'RT @taller2006: #DebateINE  #TodosConAMLO \n¡GANAMOS MI PEJE! https://t.co/DoHUKY3GuD'

# %%
at.nube(at.refina_texto(tuits, 'data/lista_negra.csv', 'debateine'))

# %%
at.analiza_menciones(tuits)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d22419fcfc50> in <module>()
# ----> 1 at.analiza_menciones(tuis)
#
# NameError: name 'tuis' is not defined
